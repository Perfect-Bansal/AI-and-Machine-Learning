# %%
import os
import random
from PIL import Image
import matplotlib.pyplot as plt

# Path to your dataset
train_dir = "/content/drive/MyDrive/AI Sem6/Week5/FruitinAmazon/train"

# Step 1: Get class directories
classes = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]

images = []
titles = []

# Step 2: Select one random image from each class
for cls in classes:
    class_path = os.path.join(train_dir, cls)

    # Get all image files (filter common formats)
    img_files = [f for f in os.listdir(class_path)
                 if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if img_files:
        img_name = random.choice(img_files)
        img_path = os.path.join(class_path, img_name)

        img = Image.open(img_path)
        images.append(img)
        titles.append(cls)

# Step 3: Plot images in grid (2 rows)
num_images = len(images)
cols = (num_images + 1) // 2  # divide into 2 rows

plt.figure(figsize=(15, 6))

for i in range(num_images):
    plt.subplot(2, cols, i + 1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
corrupted_images = []

# Iterate through each class subdirectory
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)

    if not os.path.isdir(class_path):
        continue

    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)

        try:
            # Try opening and verifying the image
            with Image.open(img_path) as img:
                img.verify()  # checks for corruption

        except (IOError, SyntaxError):
            corrupted_images.append(img_path)

            # Remove corrupted image
            os.remove(img_path)
            print(f"Removed corrupted image: {img_path}")

# Final report
if not corrupted_images:
    print("No Corrupted Images Found.")
else:
    print(f"\nTotal corrupted images removed: {len(corrupted_images)}")
# Out:
# No Corrupted Images Found.

# %%
import tensorflow as tf
# Define image size and batch size
img_height = 128 # Example image height
img_width = 128 # Example image width
batch_size = 32
validation_split = 0.2 # 80% training, 20% validation
# Create a preprocessing layer for normalization
rescale = tf.keras.layers.Rescaling(1./255) # Normalize pixel values to [0, 1]
# Create training dataset with normalization
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
train_dir,
labels='inferred',
label_mode='int',
image_size=(img_height, img_width),
interpolation='nearest',
batch_size=batch_size,
shuffle=True,
validation_split=validation_split,
subset='training',
seed=123
)
# Apply the normalization (Rescaling) to the dataset
train_ds = train_ds.map(lambda x, y: (rescale(x), y))
# Create validation dataset with normalization
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
train_dir,
labels='inferred',
label_mode='int',
image_size=(img_height, img_width),
interpolation='nearest',
batch_size=batch_size,
shuffle=False,
validation_split=validation_split,
subset='validation',
seed=123
)
# Apply the normalization (Rescaling) to the validation dataset
val_ds = val_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Set number of classes
num_classes = 6   # Corrected based on your dataset

# Input shape (change based on your dataset)
input_shape = (128, 128, 3)

model = models.Sequential()

# 🔹 Convolutional Layer 1
model.add(layers.Conv2D(
    filters=32,
    kernel_size=(3, 3),
    strides=1,
    padding='same',
    activation='relu',
    input_shape=input_shape
))

# 🔹 Pooling Layer 1
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2))

# 🔹 Convolutional Layer 2
model.add(layers.Conv2D(
    filters=32,
    kernel_size=(3, 3),
    strides=1,
    padding='same',
    activation='relu'
))

# 🔹 Pooling Layer 2
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2))

# 🔹 Flatten
model.add(layers.Flatten())

# 🔹 Fully Connected Layers
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(128, activation='relu'))

# 🔹 Output Layer
model.add(layers.Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy', # Corrected loss function
    metrics=['accuracy']
)

# Model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │     2,097,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

# Train the model
history = model.fit(
    train_ds,
    epochs=250,
    validation_data=val_ds,
    callbacks=[checkpoint, early_stopping],
    batch_size=16
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.1204 - loss: 1.9784
# Epoch 1: val_accuracy improved from None to 0.11111, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_model.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 674ms/step - accuracy: 0.1111 - loss: 2.0510 - val_accuracy: 0.1111 - val_loss: 1.7006
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.2905 - loss: 1.6748
# Epoch 2: val_accuracy improved from 0.11111 to 0.50000, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to best_model.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 624ms/step - accuracy: 0.2778 - loss: 1.6857 - val_accuracy: 0.5000 - val_loss: 1.5583
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.3542 - loss: 1.5656
# Epoch 3: val_accuracy improved from 0.50000 to 0.66667, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to best_model.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 529ms/step - accuracy: 0.3750 - loss: 1.5374 - val_accuracy: 0.6667 - val_loss: 1.3592
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.4005 - loss: 1.4112
# Epoch 4: val_accuracy improved from 0.66667 to 0.72222, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to best_model.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 532ms/step - accuracy: 0.3889 - loss: 1.3856 - val_accuracy: 0.7222 - val_loss: 1.1582
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.5295 - loss: 1.1887
# Epoch 5: val_accuracy did not improve from 0.72222
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 819ms/step - accuracy: 0.5417 - loss: 1.1808 - val_accuracy: 0.7222 - val_loss: 0.9764
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.5666 - loss: 1.0425
# Epoch 6: val_accuracy did not improve from 0.72222
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 784ms/step - accuracy: 0.5278 - loss: 1.0467 - val_accuracy: 0.6111 - val_loss: 1.4756
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6800 - loss: 0.9156
# Epoch 7: val_accuracy did not improve from 0.72222
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 548ms/step - accuracy: 0.6806 - loss: 0.9338 - val_accuracy: 0.6667 - val_loss: 0.9328
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9005 - loss: 0.6740
# Epoch 8: val_accuracy did not improve from 0.72222
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 490ms/step - accuracy: 0.8889 - loss: 0.6737 - val_accuracy: 0.7222 - val_loss: 0.7235
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8582 - loss: 0.5204
# Epoch 9: val_accuracy improved from 0.72222 to 0.83333, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: finished saving model to best_model.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 577ms/step - accuracy: 0.7778 - loss: 0.5824 - val_accuracy: 0.8333 - val_loss: 0.8765
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9705 - loss: 0.3535
# Epoch 10: val_accuracy did not improve from 0.83333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 467ms/step - accuracy: 0.9583 - loss: 0.3525 - val_accuracy: 0.5000 - val_loss: 1.1595
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.8791 - loss: 0.3990
# Epoch 11: val_accuracy did not improve from 0.83333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 830ms/step - accuracy: 0.9028 - loss: 0.3600 - val_accuracy: 0.8333 - val_loss: 0.5192
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.9705 - loss: 0.2085
# Epoch 12: val_accuracy did not improve from 0.83333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 873ms/step - accuracy: 0.9583 - loss: 0.2107 - val_accuracy: 0.8333 - val_loss: 0.8233
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.9797 - loss: 0.1597
# Epoch 13: val_accuracy did not improve from 0.83333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 526ms/step - accuracy: 0.9861 - loss: 0.1466 - val_accuracy: 0.8333 - val_loss: 0.6774
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 1.0000 - loss: 0.0700
# Epoch 14: val_accuracy improved from 0.83333 to 0.88889, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14: finished saving model to best_model.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 547ms/step - accuracy: 1.0000 - loss: 0.0747 - val_accuracy: 0.8889 - val_loss: 0.3349
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 1.0000 - loss: 0.0528
# Epoch 15: val_accuracy improved from 0.88889 to 0.94444, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: finished saving model to best_model.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 596ms/step - accuracy: 1.0000 - loss: 0.0500 - val_accuracy: 0.9444 - val_loss: 0.2017
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 1.0000 - loss: 0.0454
# Epoch 16: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 564ms/step - accuracy: 1.0000 - loss: 0.0428 - val_accuracy: 0.8333 - val_loss: 0.3020
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 17: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 468ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.8333 - val_loss: 0.4118
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 18: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 667ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.8333 - val_loss: 0.5163
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 19: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 853ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.8333 - val_loss: 0.4919
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 20: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 465ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8333 - val_loss: 0.5119
# Epoch 21/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 21: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 473ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8333 - val_loss: 0.5146
# Epoch 22/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 22: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 505ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 0.4894
# Epoch 23/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 23: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 535ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8333 - val_loss: 0.4705
# Epoch 24/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 24: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 846ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8333 - val_loss: 0.4627
# Epoch 25/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 25: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 486ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8333 - val_loss: 0.4547
# Epoch 26/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 26: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 510ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8333 - val_loss: 0.4467
# Epoch 27/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 27: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 473ms/step - accuracy: 1.0000 - loss: 9.9370e-04 - val_accuracy: 0.8333 - val_loss: 0.4412
# Epoch 28/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 1.0000 - loss: 9.0743e-04
# Epoch 28: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 485ms/step - accuracy: 1.0000 - loss: 8.7308e-04 - val_accuracy: 0.8333 - val_loss: 0.4374
# Epoch 29/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 1.0000 - loss: 8.8860e-04
# Epoch 29: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 728ms/step - accuracy: 1.0000 - loss: 7.9201e-04 - val_accuracy: 0.8333 - val_loss: 0.4321
# Epoch 30/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 1.0000 - loss: 6.3993e-04
# Epoch 30: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 880ms/step - accuracy: 1.0000 - loss: 7.2000e-04 - val_accuracy: 0.8333 - val_loss: 0.4248
# Epoch 31/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 1.0000 - loss: 7.1102e-04
# Epoch 31: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 478ms/step - accuracy: 1.0000 - loss: 6.6103e-04 - val_accuracy: 0.8333 - val_loss: 0.4144
# Epoch 32/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 1.0000 - loss: 5.2371e-04
# Epoch 32: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 574ms/step - accuracy: 1.0000 - loss: 5.7650e-04 - val_accuracy: 0.8333 - val_loss: 0.4031
# Epoch 33/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 1.0000 - loss: 5.4052e-04
# Epoch 33: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 1.0000 - loss: 5.3933e-04 - val_accuracy: 0.8333 - val_loss: 0.3930
# Epoch 34/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 1.0000 - loss: 5.3204e-04
# Epoch 34: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 552ms/step - accuracy: 1.0000 - loss: 5.1327e-04 - val_accuracy: 0.8333 - val_loss: 0.3847
# Epoch 35/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 1.0000 - loss: 4.5638e-04
# Epoch 35: val_accuracy did not improve from 0.94444
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 817ms/step - accuracy: 1.0000 - loss: 4.8677e-04 - val_accuracy: 0.8333 - val_loss: 0.3784
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
test_loss, test_acc = model.evaluate(val_ds)
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9444 - loss: 0.2017
#
# Test Loss: 0.2017
# Test Accuracy: 0.9444

# %%
# Plot training history
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy plot
ax1.plot(history.history['accuracy'], label='Training Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

# Loss plot
ax2.plot(history.history['loss'], label='Training Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# Task 6: Save and Load the Model
# Write your code here

# Save the model
model.save('fruit_classifier_cnn.h5')
print("Model saved to 'fruit_classifier_cnn.h5'")

# Load the saved model
loaded_model = tf.keras.models.load_model('fruit_classifier_cnn.h5')
print("Model loaded successfully.")

# Re-evaluate the loaded model
loaded_loss, loaded_acc = loaded_model.evaluate(val_ds)
print(f"\nLoaded Model - Test Loss: {loaded_loss:.4f}")
print(f"Loaded Model - Test Accuracy: {loaded_acc:.4f}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved to 'fruit_classifier_cnn.h5'
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step - accuracy: 0.9444 - loss: 0.2017
#
# Loaded Model - Test Loss: 0.2017
# Loaded Model - Test Accuracy: 0.9444

# %%
import tensorflow as tf

test_dir = "/content/drive/MyDrive/AI Sem6/Week5/FruitinAmazon/test"

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    image_size=(128, 128),
    batch_size=16,
    shuffle=False   # VERY IMPORTANT for correct evaluation
)
# Out:
# Found 30 files belonging to 6 classes.

# %%
test_ds = test_ds.map(lambda x, y: (x / 255.0, y))

# %%
import numpy as np

# Get predictions (probabilities)
predictions = model.predict(test_ds)

# Convert probabilities → class labels
pred_labels = np.argmax(predictions, axis=1)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step

# %%
true_labels = []

for images, labels in test_ds:
    true_labels.extend(labels.numpy())

true_labels = np.array(true_labels)

# %%
from sklearn.metrics import classification_report

class_names = classes # Use the 'classes' variable that was already extracted

print(classification_report(true_labels, pred_labels, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#      cupuacu       0.75      0.60      0.67         5
#         acai       0.57      0.80      0.67         5
#      guarana       0.80      0.80      0.80         5
#     graviola       0.56      1.00      0.71         5
#      pupunha       1.00      0.60      0.75         5
#       tucuma       1.00      0.40      0.57         5
#
#     accuracy                           0.70        30
#    macro avg       0.78      0.70      0.69        30
# weighted avg       0.78      0.70      0.69        30
